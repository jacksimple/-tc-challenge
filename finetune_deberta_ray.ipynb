# %%
import evaluate
import numpy as np
import ray

from datasets import load_dataset
from ray import tune
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer,
)

# %%
def preprocess_function(data, tokenizer):
    return tokenizer(data["text"], truncation=True)


def compute_metrics(eval_pred):
    accuracy = evaluate.load("accuracy")
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)


def model_init(trial):
    return AutoModelForSequenceClassification.from_pretrained(
        model_id, num_labels=3, id2label=id2label, label2id=label2id
    )

# %%
model_id = "microsoft/deberta-v3-large"
tokenizer = AutoTokenizer.from_pretrained(model_id)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# /home/ubuntu/Code/subv2/rayvenv/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
training_dataset = load_dataset("csv", data_files="train.csv")
training_dataset = training_dataset["train"].train_test_split(test_size=0.1, seed=42)
tokenized_dataset = training_dataset.map(
    preprocess_function, fn_kwargs={"tokenizer": tokenizer}, batched=True
)
tokenized_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 8588
#     })
#     test: Dataset({
#         features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 955
#     })
# })

# %%
id2label = {0: "NEGATIVE", 1: "POSITIVE", 2: "NEUTRAL"}
label2id = {"NEGATIVE": 0, "POSITIVE": 1, "NEUTRAL": 2}

# %%
training_args = TrainingArguments(
    output_dir="deberta_v3_base",
    learning_rate=2e-5,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    # weight_decay=0.01,
    evaluation_strategy="steps",
    save_strategy="steps",
    logging_steps=100,
    load_best_model_at_end=False,  # true checkpoints and crushes space
    push_to_hub=False,
    report_to="none",
)

trainer = Trainer(
    model=None,
    model_init=model_init,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

tune_config = {
    "learning_rate": tune.loguniform(1e-6, 1e-4),
    "per_device_train_batch_size": tune.choice([2, 4, 8, 16, 32, 64]),
    # "per_device_eval_batch_size": tune.choice([2, 4, 8, 16, 32, 64]),
    "num_train_epochs": tune.choice([2, 3]),
}

trainer.hyperparameter_search(
    direction="maximize",
    backend="ray",
    hp_space=lambda _: tune_config,
    n_trials=1,  # Set this to however many iterations you can afford
    # checkpoint_score_attr="training_iteration",
    # resources_per_trial={"cpu": 20},
    resources_per_trial={"gpu": 1},
    local_dir="~/ray_results/",
)
# Out:
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-large and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/ubuntu/Code/subv2/rayvenv/lib/python3.10/site-packages/ray/tune/tune.py:583: UserWarning: The `local_dir` argument is deprecated and will be removed. This will pass-through to set the `storage_path` for now but will raise an error in the future. You should only set the `storage_path` from now on.
#   warnings.warn(
# 2024-05-02 19:24:30,736	INFO tune.py:614 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-05-02 19:24:30,742	WARNING callback.py:136 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2024-05-02 19:24:30 (running for 00:00:00.11)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 PENDING)
#
#
# == Status ==
# Current time: 2024-05-02 19:24:35 (running for 00:00:05.15)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:24:40 (running for 00:00:10.17)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:24:45 (running for 00:00:15.19)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:24:50 (running for 00:00:20.20)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:24:55 (running for 00:00:25.22)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:00 (running for 00:00:30.23)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:05 (running for 00:00:35.25)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:11 (running for 00:00:40.27)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name            </th><th style="text-align: right;">  epoch</th><th style="text-align: right;">  eval_accuracy</th><th style="text-align: right;">  eval_loss</th><th style="text-align: right;">  eval_runtime</th><th style="text-align: right;">  eval_samples_per_second</th><th style="text-align: right;">  eval_steps_per_second</th><th style="text-align: right;">  objective</th><th>should_checkpoint  </th></tr>
# </thead>
# <tbody>
# <tr><td>_objective_99672_00000</td><td style="text-align: right;">1.85874</td><td style="text-align: right;">       0.902618</td><td style="text-align: right;">   0.298648</td><td style="text-align: right;">        3.6548</td><td style="text-align: right;">                  261.304</td><td style="text-align: right;">                 16.417</td><td style="text-align: right;">   0.902618</td><td>True               </td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# == Status ==
# Current time: 2024-05-02 19:25:16 (running for 00:00:45.30)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:21 (running for 00:00:50.32)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:26 (running for 00:00:55.34)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:31 (running for 00:01:00.35)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:36 (running for 00:01:05.37)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:41 (running for 00:01:10.39)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:46 (running for 00:01:15.40)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:51 (running for 00:01:20.42)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:25:56 (running for 00:01:25.44)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:01 (running for 00:01:30.46)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:06 (running for 00:01:35.47)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:11 (running for 00:01:40.49)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:16 (running for 00:01:45.50)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:21 (running for 00:01:50.52)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:26 (running for 00:01:55.54)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:31 (running for 00:02:00.55)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:36 (running for 00:02:05.57)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:41 (running for 00:02:10.59)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:46 (running for 00:02:15.60)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:51 (running for 00:02:20.62)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:26:56 (running for 00:02:25.63)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:01 (running for 00:02:30.65)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:06 (running for 00:02:35.65)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:11 (running for 00:02:40.67)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:16 (running for 00:02:45.69)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:21 (running for 00:02:50.71)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:26 (running for 00:02:55.72)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:31 (running for 00:03:00.74)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:36 (running for 00:03:05.75)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:41 (running for 00:03:10.77)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:46 (running for 00:03:15.79)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:51 (running for 00:03:20.81)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:27:56 (running for 00:03:25.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:28:01 (running for 00:03:30.84)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:28:06 (running for 00:03:35.85)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:28:11 (running for 00:03:40.87)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2024-05-02 19:28:16 (running for 00:03:45.88)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
# 2024-05-02 19:28:16,859	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to '/home/ubuntu/ray_results/_objective_2024-05-02_19-24-30' in 0.0023s.
# 2024-05-02 19:28:16,861	INFO tune.py:1039 -- Total run time: 226.13 seconds (226.11 seconds for the tuning loop).
# == Status ==
# Current time: 2024-05-02 19:28:16 (running for 00:03:46.11)
# Using FIFO scheduling algorithm.
# Logical resource usage: 0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A100)
# Result logdir: /tmp/ray/session_2024-05-02_19-11-24_126744_107862/artifacts/2024-05-02_19-24-30/_objective_2024-05-02_19-24-30/driver_artifacts
# Number of trials: 1/1 (1 TERMINATED)
# +------------------------+------------+-----------------+-----------------+--------------------+------------------------+-------------+
# | Trial name             | status     | loc             |   learning_rate |   num_train_epochs |   per_device_train_bat |   objective |
# |                        |            |                 |                 |                    |                ch_size |             |
# |------------------------+------------+-----------------+-----------------+--------------------+------------------------+-------------|
# | _objective_99672_00000 | TERMINATED | 10.1.0.4:109943 |     5.61152e-06 |                  2 |                     32 |    0.902618 |
# +------------------------+------------+-----------------+-----------------+--------------------+------------------------+-------------+
# BestRun(run_id='99672_00000', objective=0.9026178010471204, hyperparameters={'learning_rate': 5.61151641533451e-06, 'per_device_train_batch_size': 32, 'num_train_epochs': 2}, run_summary=<ray.tune.analysis.experiment_analysis.ExperimentAnalysis object at 0x76b52e790d00>)
